# %% [markdown]
# 1. Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.

# %%
import json

import pandas as pd

# %%
df_videogames = pd.read_csv("videogames.csv")

# %%
print(df_videogames)
# Out:
#        Unnamed: 0                                 name  \
# 0               0                           Spider-Man
# 1               1               Red Dead Redemption II
# 2               2                   Grand Theft Auto V
# 3               3                           God of War
# 4               4           Uncharted 4: A Thief's End
# ...           ...                                  ...
# 20798       20798  Enjoy Your Power, Enjoy Your Choice
# 20799       20799                           RedSun2020
# 20800       20800                              Shutter
# 20801       20801                    The Music Machine
# 20802       20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 2.
# Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_videogames = pd.read_csv("videogames.csv", index_col = 0)

# %%
df_videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# 3.
# Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
df_videogames.to_excel("videogames.xlsx")

# %%
df_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
df_videogames_excel.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# El dataframe en excel es igual que el del csv.

# %%
# importamos las librerías que necesitaremos

# Importar librería para trabajar con archivos JSON
# -----------------------------------------------------------------------
import json

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# %%
with open("files/personal.json", "r") as fichero: # introducimos el nombre de nuestro archivo json y "r" porque lo vamos a leer(read)
    personal = json.load(fichero) # igualamos el archivo cargado a una variable para tenerlo almacenad

# %%
crear una nueva variable que sea el diccionario [workers] para acceder a eso buscnaod un me´todo que existe para crear listas 
o crear un dump como jason y brimos ese jason como pandas

# %%
workers = personal["workers"]["edad"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/z0/ptwngvg97wndky1th_f_rz8r0000gp/T/ipykernel_90013/864633769.py in <module>
# ----> 1 workers = personal["workers"]["edad"] =+1
#
# TypeError: list indices must be integers or slices, not str

# %%
for worker in personal["workers"]:
    worker["nivel"] = "Senior"
    print(worker)
    print(".............")
# Out:
# {'nombre': 'Ana', 'edad': 1, 'experiencia': 5, 'nivel': 'Senior', 'salario': 50000, 'mascota': 'gatos'}
# .............
# {'nombre': 'Eva', 'edad': 1, 'experiencia': 2, 'nivel': 'Senior', 'salario': 35000}
# .............
# {'nombre': 'Marta', 'edad': 1, 'experiencia': 1, 'nivel': 'Senior', 'salario': 25000}
# .............
# {'nombre': 'Paula', 'edad': 1, 'experiencia': 3, 'nivel': 'Senior', 'salario': 35000}
# .............

# %%
with open("files/personal.json", "w") as fichero: # introducimos el nombre de nuestro archivo json y "r" porque lo vamos a leer(read)
    personal_editado = json.dump(personal,fichero) # igualamos el archivo cargado a una variable para tenerlo almacenad
